# %%
import pandas as pd
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 759

# %%
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time

# %%
city_data = []
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,})
        
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | faanui
# Processing Record 2 of Set 1 | rio grande
# Processing Record 3 of Set 1 | ancud
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | severo-kurilsk
# Processing Record 7 of Set 1 | usinsk
# Processing Record 8 of Set 1 | isangel
# Processing Record 9 of Set 1 | margate
# Processing Record 10 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | kulhudhuffushi
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | daru
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | kahului
# Processing Record 19 of Set 1 | komsomolskiy
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | guacui
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | lorengau
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | quzhou
# Processing Record 40 of Set 1 | pimentel
# Processing Record 41 of Set 1 | kaeo
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | north platte
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | moberly
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | macapa
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | deogarh
# Processing Record 8 of Set 2 | atar
# Processing Record 9 of Set 2 | carauari
# Processing Record 10 of Set 2 | kawalu
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | gat
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | sao joaquim do monte
# Processing Record 18 of Set 2 | deputatskiy
# Processing Record 19 of Set 2 | ahipara
# Processing Record 20 of Set 2 | lethem
# Processing Record 21 of Set 2 | grindavik
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | debre birhan
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | monmouth
# Processing Record 26 of Set 2 | shache
# Processing Record 27 of Set 2 | waingapu
# Processing Record 28 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 2 | hofn
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | celestun
# Processing Record 32 of Set 2 | batagay-alyta
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | korcula
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 2 | umea
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | strezhevoy
# Processing Record 42 of Set 2 | eyl
# Processing Record 43 of Set 2 | jiazi
# Processing Record 44 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | yueyang
# Processing Record 47 of Set 2 | mataura
# Processing Record 48 of Set 2 | lima duarte
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | gorontalo
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | horsham
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | aguimes
# Processing Record 7 of Set 3 | homer
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | leningradskiy
# Processing Record 11 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 12 of Set 3 | samsun
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | urengoy
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | tandil
# Processing Record 17 of Set 3 | san luis
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | puerto colombia
# Processing Record 21 of Set 3 | mehamn
# Processing Record 22 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 3 | kavaratti
# Processing Record 25 of Set 3 | caravelas
# Processing Record 26 of Set 3 | honningsvag
# Processing Record 27 of Set 3 | beloha
# Processing Record 28 of Set 3 | dvorichna
# Processing Record 29 of Set 3 | nantucket
# Processing Record 30 of Set 3 | sao joao da barra
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | shenjiamen
# Processing Record 33 of Set 3 | puerto del rosario
# Processing Record 34 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | poum
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | jaipur hat
# City not found. Skipping...
# Processing Record 42 of Set 3 | koungou
# Processing Record 43 of Set 3 | maridi
# Processing Record 44 of Set 3 | roebourne
# Processing Record 45 of Set 3 | maragogi
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | nyurba
# Processing Record 48 of Set 3 | angoram
# Processing Record 49 of Set 3 | marawi
# Processing Record 50 of Set 3 | basoko
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | guiren
# Processing Record 4 of Set 4 | cap malheureux
# Processing Record 5 of Set 4 | iracoubo
# Processing Record 6 of Set 4 | antofagasta
# Processing Record 7 of Set 4 | antalaha
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | hami
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | ayan
# Processing Record 13 of Set 4 | lazaro cardenas
# Processing Record 14 of Set 4 | ulaangom
# Processing Record 15 of Set 4 | te anau
# Processing Record 16 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | seymchan
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | elko
# Processing Record 21 of Set 4 | nicoya
# Processing Record 22 of Set 4 | canguaretama
# Processing Record 23 of Set 4 | wucheng
# Processing Record 24 of Set 4 | mecca
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | neyshabur
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | vuktyl
# Processing Record 32 of Set 4 | yuzhnyy
# Processing Record 33 of Set 4 | mutuipe
# Processing Record 34 of Set 4 | olafsvik
# Processing Record 35 of Set 4 | husavik
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | waipawa
# Processing Record 38 of Set 4 | valparaiso
# Processing Record 39 of Set 4 | raga
# Processing Record 40 of Set 4 | araouane
# Processing Record 41 of Set 4 | bonthe
# Processing Record 42 of Set 4 | praxedis guerrero
# Processing Record 43 of Set 4 | goderich
# Processing Record 44 of Set 4 | new norfolk
# Processing Record 45 of Set 4 | galle
# Processing Record 46 of Set 4 | port augusta
# Processing Record 47 of Set 4 | port elizabeth
# Processing Record 48 of Set 4 | plavinas
# Processing Record 49 of Set 4 | aklavik
# Processing Record 50 of Set 4 | abu samrah
# Processing Record 1 of Set 5 | saldanha
# Processing Record 2 of Set 5 | man
# Processing Record 3 of Set 5 | kruisfontein
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | douentza
# Processing Record 6 of Set 5 | hanzhong
# Processing Record 7 of Set 5 | buinsk
# Processing Record 8 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 5 | lowestoft
# Processing Record 10 of Set 5 | muros
# Processing Record 11 of Set 5 | livingstone
# Processing Record 12 of Set 5 | bandarbeyla
# Processing Record 13 of Set 5 | san jeronimo
# Processing Record 14 of Set 5 | coquimbo
# Processing Record 15 of Set 5 | srednekolymsk
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | santo antonio do ica
# Processing Record 18 of Set 5 | doha
# Processing Record 19 of Set 5 | nouadhibou
# Processing Record 20 of Set 5 | moose factory
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | yadgir
# Processing Record 23 of Set 5 | guangshui
# Processing Record 24 of Set 5 | charlestown
# Processing Record 25 of Set 5 | dolores
# Processing Record 26 of Set 5 | kaitangata
# Processing Record 27 of Set 5 | gualaceo
# Processing Record 28 of Set 5 | biu
# Processing Record 29 of Set 5 | athabasca
# Processing Record 30 of Set 5 | bubaque
# Processing Record 31 of Set 5 | abapo
# Processing Record 32 of Set 5 | bojaya
# City not found. Skipping...
# Processing Record 33 of Set 5 | rudnogorsk
# Processing Record 34 of Set 5 | maarianhamina
# Processing Record 35 of Set 5 | benghazi
# Processing Record 36 of Set 5 | kushiro
# Processing Record 37 of Set 5 | catamarca
# Processing Record 38 of Set 5 | jalu
# Processing Record 39 of Set 5 | oga
# Processing Record 40 of Set 5 | bairiki
# Processing Record 41 of Set 5 | mitu
# Processing Record 42 of Set 5 | amapa
# Processing Record 43 of Set 5 | riyadh
# Processing Record 44 of Set 5 | avera
# Processing Record 45 of Set 5 | tigil
# Processing Record 46 of Set 5 | teya
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | revelstoke
# Processing Record 50 of Set 5 | faya
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | bac lieu
# Processing Record 3 of Set 6 | hobyo
# Processing Record 4 of Set 6 | rimini
# Processing Record 5 of Set 6 | berezivka
# Processing Record 6 of Set 6 | meulaboh
# Processing Record 7 of Set 6 | kalemie
# Processing Record 8 of Set 6 | khani
# Processing Record 9 of Set 6 | tiznit
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | krasnoselkup
# Processing Record 12 of Set 6 | humberto de campos
# Processing Record 13 of Set 6 | phalaborwa
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | san patricio
# Processing Record 16 of Set 6 | drayton valley
# Processing Record 17 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 6 | saint-augustin
# Processing Record 19 of Set 6 | jumla
# Processing Record 20 of Set 6 | tagusao
# Processing Record 21 of Set 6 | broken hill
# Processing Record 22 of Set 6 | altamira
# Processing Record 23 of Set 6 | lamar
# Processing Record 24 of Set 6 | inirida
# Processing Record 25 of Set 6 | changchun
# Processing Record 26 of Set 6 | troy
# Processing Record 27 of Set 6 | hambantota
# Processing Record 28 of Set 6 | bani walid
# Processing Record 29 of Set 6 | palmer
# Processing Record 30 of Set 6 | harbour breton
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | villa carlos paz
# Processing Record 33 of Set 6 | huambo
# Processing Record 34 of Set 6 | ambulu
# Processing Record 35 of Set 6 | olavarria
# Processing Record 36 of Set 6 | goure
# Processing Record 37 of Set 6 | isla vista
# Processing Record 38 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | non sang
# Processing Record 41 of Set 6 | labuhan
# Processing Record 42 of Set 6 | omsukchan
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | corinto
# Processing Record 46 of Set 6 | baie-comeau
# Processing Record 47 of Set 6 | kamaishi
# Processing Record 48 of Set 6 | katangli
# Processing Record 49 of Set 6 | grand gaube
# Processing Record 50 of Set 6 | duncan
# Processing Record 1 of Set 7 | chapais
# Processing Record 2 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 7 | takoradi
# Processing Record 4 of Set 7 | coxim
# Processing Record 5 of Set 7 | old road
# City not found. Skipping...
# Processing Record 6 of Set 7 | nador
# Processing Record 7 of Set 7 | nanakuli
# Processing Record 8 of Set 7 | shitanjing
# Processing Record 9 of Set 7 | kichera
# Processing Record 10 of Set 7 | kochi
# Processing Record 11 of Set 7 | gualaco
# Processing Record 12 of Set 7 | jinchang
# Processing Record 13 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | clyde river
# Processing Record 16 of Set 7 | kalianget
# Processing Record 17 of Set 7 | walvis bay
# Processing Record 18 of Set 7 | decatur
# Processing Record 19 of Set 7 | ugoofaaru
# Processing Record 20 of Set 7 | kysyl-syr
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | baykit
# Processing Record 23 of Set 7 | porto santo
# Processing Record 24 of Set 7 | shahpur
# Processing Record 25 of Set 7 | chingirlau
# Processing Record 26 of Set 7 | mildura
# Processing Record 27 of Set 7 | mayo
# Processing Record 28 of Set 7 | camacha
# Processing Record 29 of Set 7 | guerrero negro
# Processing Record 30 of Set 7 | maibong
# Processing Record 31 of Set 7 | erkelenz
# Processing Record 32 of Set 7 | kose-uuemoisa
# City not found. Skipping...
# Processing Record 33 of Set 7 | lucea
# Processing Record 34 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 7 | hebi
# Processing Record 36 of Set 7 | karuzi
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | port-de-bouc
# Processing Record 40 of Set 7 | chuzhou
# Processing Record 41 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 7 | burnie
# Processing Record 43 of Set 7 | dhidhdhoo
# Processing Record 44 of Set 7 | praya
# Processing Record 45 of Set 7 | kaseda
# Processing Record 46 of Set 7 | marzuq
# Processing Record 47 of Set 7 | kazerun
# Processing Record 48 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | kulachi
# Processing Record 50 of Set 7 | mana
# Processing Record 1 of Set 8 | leh
# Processing Record 2 of Set 8 | ola
# Processing Record 3 of Set 8 | puerto escondido
# Processing Record 4 of Set 8 | senanga
# Processing Record 5 of Set 8 | buin
# Processing Record 6 of Set 8 | lensk
# Processing Record 7 of Set 8 | clermont
# Processing Record 8 of Set 8 | dalvik
# Processing Record 9 of Set 8 | ormara
# Processing Record 10 of Set 8 | harihar
# Processing Record 11 of Set 8 | baruun-urt
# Processing Record 12 of Set 8 | dalby
# Processing Record 13 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 8 | scalloway
# City not found. Skipping...
# Processing Record 15 of Set 8 | metu
# Processing Record 16 of Set 8 | batemans bay
# Processing Record 17 of Set 8 | constantine
# Processing Record 18 of Set 8 | rio verde de mato grosso
# Processing Record 19 of Set 8 | marystown
# Processing Record 20 of Set 8 | bonavista
# Processing Record 21 of Set 8 | pandamatenga
# Processing Record 22 of Set 8 | boyolangu
# Processing Record 23 of Set 8 | kolbermoor
# Processing Record 24 of Set 8 | tiksi
# Processing Record 25 of Set 8 | naze
# Processing Record 26 of Set 8 | peru
# Processing Record 27 of Set 8 | miri
# Processing Record 28 of Set 8 | kerema
# Processing Record 29 of Set 8 | dunedin
# Processing Record 30 of Set 8 | tabalosos
# Processing Record 31 of Set 8 | ghanzi
# Processing Record 32 of Set 8 | cairns
# Processing Record 33 of Set 8 | kavieng
# Processing Record 34 of Set 8 | preobrazheniye
# Processing Record 35 of Set 8 | irbit
# Processing Record 36 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 8 | shyryayeve
# Processing Record 38 of Set 8 | kungurtug
# Processing Record 39 of Set 8 | comodoro rivadavia
# Processing Record 40 of Set 8 | duz
# City not found. Skipping...
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | patnos
# Processing Record 44 of Set 8 | chom bung
# City not found. Skipping...
# Processing Record 45 of Set 8 | apaxtla
# City not found. Skipping...
# Processing Record 46 of Set 8 | siderno
# Processing Record 47 of Set 8 | kiama
# Processing Record 48 of Set 8 | bayan
# Processing Record 49 of Set 8 | ucluelet
# Processing Record 50 of Set 8 | zhob
# Processing Record 1 of Set 9 | indianola
# Processing Record 2 of Set 9 | nikolskoye
# Processing Record 3 of Set 9 | kargasok
# Processing Record 4 of Set 9 | fortuna
# Processing Record 5 of Set 9 | moratuwa
# Processing Record 6 of Set 9 | gbarnga
# Processing Record 7 of Set 9 | kieta
# Processing Record 8 of Set 9 | nkhata bay
# Processing Record 9 of Set 9 | palauig
# Processing Record 10 of Set 9 | vestmannaeyjar
# Processing Record 11 of Set 9 | port hardy
# Processing Record 12 of Set 9 | khandyga
# Processing Record 13 of Set 9 | bukachacha
# Processing Record 14 of Set 9 | makakilo city
# Processing Record 15 of Set 9 | pangnirtung
# Processing Record 16 of Set 9 | roblin
# Processing Record 17 of Set 9 | talaya
# Processing Record 18 of Set 9 | taltal
# Processing Record 19 of Set 9 | boysun
# Processing Record 20 of Set 9 | ximei
# Processing Record 21 of Set 9 | solnechnyy
# Processing Record 22 of Set 9 | usolye
# Processing Record 23 of Set 9 | forio
# Processing Record 24 of Set 9 | naregal
# Processing Record 25 of Set 9 | brahmapuri
# City not found. Skipping...
# Processing Record 26 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 9 | gornopravdinsk
# Processing Record 28 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 29 of Set 9 | gambela
# Processing Record 30 of Set 9 | koutsouras
# Processing Record 31 of Set 9 | mount isa
# Processing Record 32 of Set 9 | raudeberg
# Processing Record 33 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 9 | oranjemund
# Processing Record 35 of Set 9 | port hedland
# Processing Record 36 of Set 9 | oktyabrskiy
# Processing Record 37 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 9 | parabel
# Processing Record 39 of Set 9 | lavrentiya
# Processing Record 40 of Set 9 | alihe
# Processing Record 41 of Set 9 | pitimbu
# Processing Record 42 of Set 9 | kharitonovo
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | tessalit
# Processing Record 45 of Set 9 | saint-pierre
# Processing Record 46 of Set 9 | port lincoln
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | phibun mangsahan
# Processing Record 49 of Set 9 | powell river
# Processing Record 50 of Set 9 | khristoforovo
# City not found. Skipping...
# Processing Record 1 of Set 10 | bow island
# Processing Record 2 of Set 10 | itoman
# Processing Record 3 of Set 10 | puro
# Processing Record 4 of Set 10 | pasighat
# Processing Record 5 of Set 10 | birobidzhan
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | tambun
# Processing Record 8 of Set 10 | sisimiut
# Processing Record 9 of Set 10 | basco
# Processing Record 10 of Set 10 | berlevag
# Processing Record 11 of Set 10 | vrangel
# Processing Record 12 of Set 10 | stephenville
# Processing Record 13 of Set 10 | fairbanks
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | harper
# Processing Record 16 of Set 10 | haines junction
# Processing Record 17 of Set 10 | shetpe
# Processing Record 18 of Set 10 | khandbari
# Processing Record 19 of Set 10 | guangyuan
# Processing Record 20 of Set 10 | khabary
# Processing Record 21 of Set 10 | samos
# Processing Record 22 of Set 10 | roma
# Processing Record 23 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 10 | bom jesus
# Processing Record 25 of Set 10 | bijie
# Processing Record 26 of Set 10 | karpogory
# Processing Record 27 of Set 10 | ornskoldsvik
# Processing Record 28 of Set 10 | sassandra
# Processing Record 29 of Set 10 | mananjary
# Processing Record 30 of Set 10 | concarneau
# Processing Record 31 of Set 10 | seoul
# Processing Record 32 of Set 10 | yamada
# Processing Record 33 of Set 10 | perbaungan
# Processing Record 34 of Set 10 | saint-paul
# Processing Record 35 of Set 10 | sindou
# Processing Record 36 of Set 10 | cangucu
# Processing Record 37 of Set 10 | whitehaven
# Processing Record 38 of Set 10 | fontem
# Processing Record 39 of Set 10 | bilma
# Processing Record 40 of Set 10 | krasnorechenskiy
# Processing Record 41 of Set 10 | nortelandia
# Processing Record 42 of Set 10 | nuuk
# Processing Record 43 of Set 10 | paulo afonso
# Processing Record 44 of Set 10 | natal
# Processing Record 45 of Set 10 | nemuro
# Processing Record 46 of Set 10 | aland
# Processing Record 47 of Set 10 | yeppoon
# Processing Record 48 of Set 10 | bandar-e lengeh
# Processing Record 49 of Set 10 | idritsa
# Processing Record 50 of Set 10 | taybad
# Processing Record 1 of Set 11 | vila
# Processing Record 2 of Set 11 | merauke
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | pula
# Processing Record 5 of Set 11 | vanavara
# Processing Record 6 of Set 11 | palaia fokaia
# Processing Record 7 of Set 11 | tutoia
# Processing Record 8 of Set 11 | juegang
# Processing Record 9 of Set 11 | skjervoy
# Processing Record 10 of Set 11 | roald
# Processing Record 11 of Set 11 | shagonar
# Processing Record 12 of Set 11 | acajutla
# Processing Record 13 of Set 11 | bereda
# Processing Record 14 of Set 11 | asfi
# Processing Record 15 of Set 11 | cockburn town
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | wahiawa
# Processing Record 18 of Set 11 | loreto
# Processing Record 19 of Set 11 | zhucheng
# Processing Record 20 of Set 11 | college
# Processing Record 21 of Set 11 | svobodnyy
# Processing Record 22 of Set 11 | praia da vitoria
# Processing Record 23 of Set 11 | taoudenni
# Processing Record 24 of Set 11 | andenes
# Processing Record 25 of Set 11 | yuzhno-kurilsk
# Processing Record 26 of Set 11 | akyab
# Processing Record 27 of Set 11 | palhoca
# Processing Record 28 of Set 11 | klichka
# Processing Record 29 of Set 11 | bunesti
# Processing Record 30 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 11 | wamba
# Processing Record 32 of Set 11 | tilichiki
# Processing Record 33 of Set 11 | angra
# City not found. Skipping...
# Processing Record 34 of Set 11 | nanortalik
# Processing Record 35 of Set 11 | sabha
# Processing Record 36 of Set 11 | talcahuano
# Processing Record 37 of Set 11 | surgut
# Processing Record 38 of Set 11 | shu
# Processing Record 39 of Set 11 | san quintin
# Processing Record 40 of Set 11 | touba
# Processing Record 41 of Set 11 | sharanga
# Processing Record 42 of Set 11 | agadez
# Processing Record 43 of Set 11 | pucallpa
# Processing Record 44 of Set 11 | brenham
# Processing Record 45 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 11 | evensk
# Processing Record 47 of Set 11 | roanoke rapids
# Processing Record 48 of Set 11 | lishu
# Processing Record 49 of Set 11 | tokonou
# Processing Record 50 of Set 11 | zirgan
# Processing Record 1 of Set 12 | matalom
# Processing Record 2 of Set 12 | inongo
# Processing Record 3 of Set 12 | polis
# Processing Record 4 of Set 12 | mount pleasant
# Processing Record 5 of Set 12 | sladkovo
# Processing Record 6 of Set 12 | turayf
# Processing Record 7 of Set 12 | dhanera
# Processing Record 8 of Set 12 | viedma
# Processing Record 9 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 10 of Set 12 | sao filipe
# Processing Record 11 of Set 12 | burnham
# Processing Record 12 of Set 12 | banda aceh
# Processing Record 13 of Set 12 | awjilah
# Processing Record 14 of Set 12 | bayangol
# Processing Record 15 of Set 12 | santa barbara
# Processing Record 16 of Set 12 | korla
# Processing Record 17 of Set 12 | lata
# Processing Record 18 of Set 12 | mao
# Processing Record 19 of Set 12 | nizhneangarsk
# Processing Record 20 of Set 12 | zhigansk
# Processing Record 21 of Set 12 | kitami
# Processing Record 22 of Set 12 | henties bay
# Processing Record 23 of Set 12 | iquique
# Processing Record 24 of Set 12 | sola
# Processing Record 25 of Set 12 | shubarshi
# Processing Record 26 of Set 12 | hammerfest
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | acari
# Processing Record 29 of Set 12 | contai
# Processing Record 30 of Set 12 | susono
# Processing Record 31 of Set 12 | platanos
# Processing Record 32 of Set 12 | syracuse
# Processing Record 33 of Set 12 | ryki
# Processing Record 34 of Set 12 | yulara
# Processing Record 35 of Set 12 | nola
# Processing Record 36 of Set 12 | vanino
# Processing Record 37 of Set 12 | nyrob
# Processing Record 38 of Set 12 | komarikhinskiy
# Processing Record 39 of Set 12 | pathein
# Processing Record 40 of Set 12 | nioaque
# Processing Record 41 of Set 12 | baghdad
# Processing Record 42 of Set 12 | lang suan
# Processing Record 43 of Set 12 | acapulco
# Processing Record 44 of Set 12 | lima
# Processing Record 45 of Set 12 | makokou
# Processing Record 46 of Set 12 | coahuayana
# Processing Record 47 of Set 12 | portland
# Processing Record 48 of Set 12 | belaya gora
# Processing Record 49 of Set 12 | verkhniy fiagdon
# Processing Record 50 of Set 12 | rosetown
# Processing Record 1 of Set 13 | maltahohe
# Processing Record 2 of Set 13 | rizhao
# Processing Record 3 of Set 13 | arlit
# Processing Record 4 of Set 13 | berdigestyakh
# Processing Record 5 of Set 13 | khilok
# Processing Record 6 of Set 13 | kaka
# Processing Record 7 of Set 13 | canutama
# Processing Record 8 of Set 13 | matay
# Processing Record 9 of Set 13 | tecoanapa
# Processing Record 10 of Set 13 | beringovskiy
# Processing Record 11 of Set 13 | hervey bay
# Processing Record 12 of Set 13 | mezen
# Processing Record 13 of Set 13 | bhatkal
# Processing Record 14 of Set 13 | taguatinga
# Processing Record 15 of Set 13 | denpasar
# Processing Record 16 of Set 13 | narsaq
# Processing Record 17 of Set 13 | marsa matruh
# Processing Record 18 of Set 13 | viru
# Processing Record 19 of Set 13 | jaciara
# Processing Record 20 of Set 13 | kamenka
# Processing Record 21 of Set 13 | quang ngai
# Processing Record 22 of Set 13 | tual
# Processing Record 23 of Set 13 | burica
# City not found. Skipping...
# Processing Record 24 of Set 13 | phangnga
# Processing Record 25 of Set 13 | hamilton
# Processing Record 26 of Set 13 | bilibino
# Processing Record 27 of Set 13 | ca mau
# Processing Record 28 of Set 13 | linxia
# Processing Record 29 of Set 13 | broome
# Processing Record 30 of Set 13 | scottsbluff
# Processing Record 31 of Set 13 | parkes
# Processing Record 32 of Set 13 | tarakan
# Processing Record 33 of Set 13 | carutapera
# Processing Record 34 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 13 | rocha
# Processing Record 36 of Set 13 | zarubino
# Processing Record 37 of Set 13 | mwingi
# Processing Record 38 of Set 13 | letlhakeng
# Processing Record 39 of Set 13 | heihe
# Processing Record 40 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 13 | cam ranh
# Processing Record 42 of Set 13 | orlik
# Processing Record 43 of Set 13 | soni
# Processing Record 44 of Set 13 | tomatlan
# Processing Record 45 of Set 13 | gulu
# Processing Record 46 of Set 13 | ibra
# Processing Record 47 of Set 13 | menongue
# Processing Record 48 of Set 13 | mopti
# Processing Record 49 of Set 13 | tabou
# Processing Record 50 of Set 13 | salinopolis
# Processing Record 1 of Set 14 | taos
# Processing Record 2 of Set 14 | pahrump
# Processing Record 3 of Set 14 | santa maria
# Processing Record 4 of Set 14 | asyut
# Processing Record 5 of Set 14 | luwingu
# Processing Record 6 of Set 14 | costinesti
# Processing Record 7 of Set 14 | sivas
# Processing Record 8 of Set 14 | moissala
# Processing Record 9 of Set 14 | griffith
# Processing Record 10 of Set 14 | elizabeth city
# Processing Record 11 of Set 14 | gorom-gorom
# Processing Record 12 of Set 14 | turki
# Processing Record 13 of Set 14 | crotone
# Processing Record 14 of Set 14 | moerai
# Processing Record 15 of Set 14 | naryan-mar
# Processing Record 16 of Set 14 | shelburne
# Processing Record 17 of Set 14 | trairi
# Processing Record 18 of Set 14 | biltine
# Processing Record 19 of Set 14 | kathmandu
# Processing Record 20 of Set 14 | peniche
# Processing Record 21 of Set 14 | mitchell
# Processing Record 22 of Set 14 | opuwo
# Processing Record 23 of Set 14 | san juan
# Processing Record 24 of Set 14 | vestmanna
# Processing Record 25 of Set 14 | lagoa
# Processing Record 26 of Set 14 | cerro cama
# Processing Record 27 of Set 14 | vawkavysk
# Processing Record 28 of Set 14 | tsaratanana
# Processing Record 29 of Set 14 | teguldet
# Processing Record 30 of Set 14 | sinnamary
# Processing Record 31 of Set 14 | ipixuna
# Processing Record 32 of Set 14 | yichang
# Processing Record 33 of Set 14 | fairfield
# Processing Record 34 of Set 14 | houston
# Processing Record 35 of Set 14 | cerkezkoy
# Processing Record 36 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 14 | wanaka
# Processing Record 38 of Set 14 | north bend
# Processing Record 39 of Set 14 | ha giang
# Processing Record 40 of Set 14 | manggar
# Processing Record 41 of Set 14 | kankan
# Processing Record 42 of Set 14 | martapura
# Processing Record 43 of Set 14 | rexburg
# Processing Record 44 of Set 14 | baherden
# Processing Record 45 of Set 14 | quatre cocos
# Processing Record 46 of Set 14 | sangar
# Processing Record 47 of Set 14 | boffa
# Processing Record 48 of Set 14 | troitskoye
# Processing Record 49 of Set 14 | necochea
# Processing Record 50 of Set 14 | hapao
# Processing Record 1 of Set 15 | los llanos de aridane
# Processing Record 2 of Set 15 | tawzar
# City not found. Skipping...
# Processing Record 3 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 4 of Set 15 | kisangani
# Processing Record 5 of Set 15 | asau
# Processing Record 6 of Set 15 | tombouctou
# Processing Record 7 of Set 15 | xichang
# Processing Record 8 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 15 | belogorsk
# Processing Record 10 of Set 15 | otane
# Processing Record 11 of Set 15 | key west
# Processing Record 12 of Set 15 | yiyang
# Processing Record 13 of Set 15 | nara
# Processing Record 14 of Set 15 | fare
# Processing Record 15 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 15 | saint joseph
# Processing Record 17 of Set 15 | launceston
# Processing Record 18 of Set 15 | gimli
# Processing Record 19 of Set 15 | barbosa ferraz
# Processing Record 20 of Set 15 | pervomayskoye
# Processing Record 21 of Set 15 | novosysoyevka
# Processing Record 22 of Set 15 | canico
# Processing Record 23 of Set 15 | nybro
# Processing Record 24 of Set 15 | pisco
# Processing Record 25 of Set 15 | porto velho
# Processing Record 26 of Set 15 | ballina
# Processing Record 27 of Set 15 | chara
# Processing Record 28 of Set 15 | dvinskoy
# Processing Record 29 of Set 15 | westport
# Processing Record 30 of Set 15 | anaconda
# Processing Record 31 of Set 15 | qena
# Processing Record 32 of Set 15 | chardara
# Processing Record 33 of Set 15 | kovur
# Processing Record 34 of Set 15 | hauterive
# Processing Record 35 of Set 15 | mastic beach
# Processing Record 36 of Set 15 | kasongo-lunda
# Processing Record 37 of Set 15 | kholm
# Processing Record 38 of Set 15 | okhotsk
# Processing Record 39 of Set 15 | sinjar
# Processing Record 40 of Set 15 | barsovo
# Processing Record 41 of Set 15 | abeokuta
# Processing Record 42 of Set 15 | gavle
# Processing Record 43 of Set 15 | imeni poliny osipenko
# Processing Record 44 of Set 15 | oktyabrskoye
# Processing Record 45 of Set 15 | sandakan
# Processing Record 46 of Set 15 | yagodnoye
# Processing Record 47 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 15 | deep river
# Processing Record 49 of Set 15 | mitsamiouli
# Processing Record 50 of Set 15 | vydrino
# Processing Record 1 of Set 16 | bocas del toro
# Processing Record 2 of Set 16 | thinadhoo
# Processing Record 3 of Set 16 | christchurch
# Processing Record 4 of Set 16 | seymour
# Processing Record 5 of Set 16 | ginda
# Processing Record 6 of Set 16 | beachwood
# Processing Record 7 of Set 16 | trincomalee
# Processing Record 8 of Set 16 | umm lajj
# Processing Record 9 of Set 16 | sao miguel do araguaia

# %%
len(city_data)
# Out:
# 701

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui      PF -16.4833 -151.7500     80.04        77         100
# 1      Rio Grande      BR -32.0350  -52.0986     93.31        64           0
# 2           Ancud      CL -41.8697  -73.8203     65.73        87          73
# 3          Hasaki      JP  35.7333  140.8333     32.40        48          17
# 4          Barrow      US  71.2906 -156.7887    -23.78        76           0
# 5  Severo-Kurilsk      RU  50.6789  156.1250     29.62        87         100
# 6          Usinsk      RU  65.9939   57.5281     19.33        96         100
# 7         Isangel      VU -19.5500  169.2667     77.11        94         100
# 8         Margate      GB  51.3813    1.3862     48.96        80          93
# 9     Port Alfred      ZA -33.5906   26.8910     72.46        80          86
#
#    Wind Speed Current Description
# 0       18.41     overcast clouds
# 1       17.47           clear sky
# 2        6.15          light rain
# 3       12.39          few clouds
# 4        4.61                haze
# 5        8.03          light snow
# 6        9.28          light snow
# 7        7.20     overcast clouds
# 8       13.18     overcast clouds
# 9       17.20     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
